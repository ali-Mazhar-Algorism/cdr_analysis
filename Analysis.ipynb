# %%
import pandas as pd

# %%
raw_data = pd.read_excel('data/923214104372.xls')

# %%
raw_data.head()
# Out:
#    Sr #  Unnamed: 1     Call Type  Unnamed: 3       A-Party  Unnamed: 5  \
# 0     1         NaN      Outgoing         NaN  923214104372         NaN
# 1     2         NaN      Outgoing         NaN  923214104372         NaN
# 2     3         NaN  Outgoing SMS         NaN  923214104372         NaN
# 3     4         NaN  Incoming SMS         NaN  923214104372         NaN
# 4     5         NaN  Incoming SMS         NaN  923214104372         NaN
#
#         B-Party  Unnamed: 7         Date & Time  Unnamed: 9  ...  Unnamed: 16  \
# 0   03028480542         NaN 2023-09-01 09:54:14         NaN  ...          NaN
# 1   03028480542         NaN 2023-09-01 09:56:52         NaN  ...          NaN
# 2          5299         NaN 2023-09-01 09:57:09         NaN  ...          NaN
# 3      35323939         NaN 2023-09-01 09:57:21         NaN  ...          NaN
# 4  923049585110         NaN 2023-09-01 10:11:24         NaN  ...          NaN
#
#                                                 Site  Unnamed: 18  \
# 0  USHD8873__S_Imamaia colony GT Road Shadhra war...          NaN
# 1  USHD8873__S_Imamaia colony GT Road Shadhra war...          NaN
# 2  USHD8873__S_Imamaia colony GT Road Shadhra war...          NaN
# 3  USHD8873__S_Imamaia colony GT Road Shadhra war...          NaN
# 4  USHD8873__S_Imamaia colony GT Road Shadhra war...          NaN
#
#    Longitude and Latitude  Unnamed: 20  Node ID  Unnamed: 22  IP  Unnamed: 24  \
# 0                     NaN          NaN      NaN          NaN NaN          NaN
# 1                     NaN          NaN      NaN          NaN NaN          NaN
# 2                     NaN          NaN      NaN          NaN NaN          NaN
# 3                     NaN          NaN      NaN          NaN NaN          NaN
# 4                     NaN          NaN      NaN          NaN NaN          NaN
#
#    Port
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 26 columns]

# %%
columns_to_remove = raw_data.filter(regex=r'^Unnamed').columns
columns_to_remove
# Out:
# Index(['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9',
#        'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16', 'Unnamed: 18',
#        'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24'],
#       dtype='object')

# %%
data = raw_data.drop(labels=columns_to_remove, axis=1)
data = data.drop(labels="Sr #", axis=1)
data.columns
# Out:
# Index(['Call Type', 'A-Party', 'B-Party', 'Date & Time', 'Duration', 'Cell ID',
#        'IMEI', 'IMSI', 'Site', 'Longitude and Latitude', 'Node ID', 'IP',
#        'Port'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Call Type', 'A-Party', 'B-Party', 'Date & Time', 'Duration', 'Cell ID',
#        'IMEI', 'IMSI', 'Site', 'Longitude and Latitude', 'Node ID', 'IP',
#        'Port'],
#       dtype='object')

# %%
print("The length of the dataframe is {}".format(len(data)))
# Out:
# The length of the dataframe is 1587

# %%
for column in data.columns:
    print('{}: {}'.format(column, len(data[column].unique())))
# Out:
# Call Type: 4
# A-Party: 1
# B-Party: 166
# Date & Time: 1587
# Duration: 311
# Cell ID: 94
# IMEI: 2
# IMSI: 1
# Site: 79
# Longitude and Latitude: 1
# Node ID: 1
# IP: 1
# Port: 1

# %%
data.count()
# Out:
# Call Type                 1587
# A-Party                   1587
# B-Party                   1587
# Date & Time               1587
# Duration                  1587
# Cell ID                   1587
# IMEI                      1587
# IMSI                      1587
# Site                      1587
# Longitude and Latitude       0
# Node ID                      0
# IP                           0
# Port                         0
# dtype: int64

# %%
threshold = len(data) * 0.25
# Drop columns that do not have at least the threshold number of non-NaN values
df_cleaned = data.dropna(axis=1, thresh=threshold)
# Display the cleaned DataFrame
df_cleaned
# Out:
#          Call Type       A-Party         B-Party         Date & Time  \
# 0         Outgoing  923214104372     03028480542 2023-09-01 09:54:14
# 1         Outgoing  923214104372     03028480542 2023-09-01 09:56:52
# 2     Outgoing SMS  923214104372            5299 2023-09-01 09:57:09
# 3     Incoming SMS  923214104372        35323939 2023-09-01 09:57:21
# 4     Incoming SMS  923214104372    923049585110 2023-09-01 10:11:24
# ...            ...           ...             ...                 ...
# 1582  Incoming SMS  923214104372  53455454494E47 2023-11-18 11:45:13
# 1583  Incoming SMS  923214104372  53455454494E47 2023-11-18 11:45:31
# 1584  Incoming SMS  923214104372            pple 2023-11-18 11:46:01
# 1585  Outgoing SMS  923214104372          005126 2023-11-18 11:46:35
# 1586  Incoming SMS  923214104372            pple 2023-11-18 12:01:05
#
#       Duration   Cell ID             IMEI             IMSI  \
# 0          134  6E40FEB6  354121934453580  410010127966065
# 1           18  6E40FEB6  354121934453580  410010127966065
# 2            0  6E40FEB6  354121934453580  410010127966065
# 3            0  6E40FEB6  354121934453580  410010127966065
# 4            0  6E40FEB6  354121934453580  410010127966065
# ...        ...       ...              ...              ...
# 1582         0  3F300000  355066960060000  410010127966065
# 1583         0  3F300000  355066960060000  410010127966065
# 1584         0   80a3068  355066960060000  410010127966065
# 1585         0   80a3068  355066960060000  410010127966065
# 1586         0   80a3068  355066960060000  410010127966065
#
#                                                    Site
# 0     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 1     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 2     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 3     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 4     USHD8873__S_Imamaia colony GT Road Shadhra war...
# ...                                                 ...
# 1582                                                  ?
# 1583                                                  ?
# 1584                                                  ?
# 1585                                                  ?
# 1586                                                  ?
#
# [1587 rows x 9 columns]

# %%
print("Number of columns dropped {}".format(len(data.columns) - len(df_cleaned.columns)))
# Out:
# Number of columns dropped 4

# %%
df_cleaned['Call Type'].unique()
# Out:
# array(['Outgoing', 'Outgoing SMS', 'Incoming SMS', 'InComing'],
#       dtype=object)

# %%
df_cleaned.head()
# Out:
#       Call Type       A-Party       B-Party         Date & Time  Duration  \
# 0      Outgoing  923214104372   03028480542 2023-09-01 09:54:14       134
# 1      Outgoing  923214104372   03028480542 2023-09-01 09:56:52        18
# 2  Outgoing SMS  923214104372          5299 2023-09-01 09:57:09         0
# 3  Incoming SMS  923214104372      35323939 2023-09-01 09:57:21         0
# 4  Incoming SMS  923214104372  923049585110 2023-09-01 10:11:24         0
#
#     Cell ID             IMEI             IMSI  \
# 0  6E40FEB6  354121934453580  410010127966065
# 1  6E40FEB6  354121934453580  410010127966065
# 2  6E40FEB6  354121934453580  410010127966065
# 3  6E40FEB6  354121934453580  410010127966065
# 4  6E40FEB6  354121934453580  410010127966065
#
#                                                 Site
# 0  USHD8873__S_Imamaia colony GT Road Shadhra war...
# 1  USHD8873__S_Imamaia colony GT Road Shadhra war...
# 2  USHD8873__S_Imamaia colony GT Road Shadhra war...
# 3  USHD8873__S_Imamaia colony GT Road Shadhra war...
# 4  USHD8873__S_Imamaia colony GT Road Shadhra war...

# %%
df_cleaned[((df_cleaned['Call Type'] == 'InComing') | (df_cleaned['Call Type'] == 'Outgoing')) & (df_cleaned['Duration'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Call Type, A-Party, B-Party, Date & Time, Duration, Cell ID, IMEI, IMSI, Site]
# Index: []

# %%
call_data = df_cleaned[((df_cleaned['Call Type'] == 'InComing') | (df_cleaned['Call Type'] == 'Outgoing'))]

# %%
call_data
# Out:
#      Call Type       A-Party      B-Party         Date & Time  Duration  \
# 0     Outgoing  923214104372  03028480542 2023-09-01 09:54:14       134
# 1     Outgoing  923214104372  03028480542 2023-09-01 09:56:52        18
# 6     Outgoing  923214104372  03049585110 2023-09-01 10:11:34        59
# 7     InComing  923214104372  03214827411 2023-09-01 10:25:23        24
# 8     Outgoing  923214104372  03214453575 2023-09-01 10:33:02      1153
# ...        ...           ...          ...                 ...       ...
# 1572  InComing  923214104372  03105383978 2023-11-17 16:54:35        24
# 1573  Outgoing  923214104372  03002520080 2023-11-17 17:55:08      1122
# 1574  Outgoing  923214104372  03258069317 2023-11-17 21:00:42       279
# 1577  Outgoing  923214104372  03002520080 2023-11-18 08:27:21        29
# 1578  Outgoing  923214104372  03002520080 2023-11-18 08:35:13       103
#
#        Cell ID             IMEI             IMSI  \
# 0     6E40FEB6  354121934453580  410010127966065
# 1     6E40FEB6  354121934453580  410010127966065
# 6     6E40FEB6  354121934453580  410010127966065
# 7     6E40FEB6  354121934453580  410010127966065
# 8     6E40FEB6  354121934453580  410010127966065
# ...        ...              ...              ...
# 1572  3F30596B  354121934453580  410010127966065
# 1573  3F30596B  354121934453580  410010127966065
# 1574  3F30596B  354121934453580  410010127966065
# 1577  3F30596B  354121934453580  410010127966065
# 1578  3F30596B  354121934453580  410010127966065
#
#                                                    Site
# 0     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 1     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 6     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 7     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 8     USHD8873__S_Imamaia colony GT Road Shadhra war...
# ...                                                 ...
# 1572  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1573  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1574  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1577  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1578  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
#
# [799 rows x 9 columns]

# %%
assert len(call_data['Call Type'].unique()) == 2

# %%
call_data['Call Type'].count()
# Out:
# 799

# %%
# Merge DataFrames with an indicator
df_merged = df_cleaned.merge(call_data, how='outer', indicator=True)
sms_data = df_merged[df_merged['_merge'] == 'left_only'].drop(columns=['_merge'])

# %%
sms_data
# Out:
#          Call Type       A-Party         B-Party         Date & Time  \
# 2     Outgoing SMS  923214104372            5299 2023-09-01 09:57:09
# 3     Incoming SMS  923214104372        35323939 2023-09-01 09:57:21
# 4     Incoming SMS  923214104372    923049585110 2023-09-01 10:11:24
# 5     Incoming SMS  923214104372    923049585110 2023-09-01 10:11:25
# 9     Incoming SMS  923214104372        4A617A7A 2023-09-01 10:43:04
# ...            ...           ...             ...                 ...
# 1582  Incoming SMS  923214104372  53455454494E47 2023-11-18 11:45:13
# 1583  Incoming SMS  923214104372  53455454494E47 2023-11-18 11:45:31
# 1584  Incoming SMS  923214104372            pple 2023-11-18 11:46:01
# 1585  Outgoing SMS  923214104372          005126 2023-11-18 11:46:35
# 1586  Incoming SMS  923214104372            pple 2023-11-18 12:01:05
#
#       Duration   Cell ID             IMEI             IMSI  \
# 2            0  6E40FEB6  354121934453580  410010127966065
# 3            0  6E40FEB6  354121934453580  410010127966065
# 4            0  6E40FEB6  354121934453580  410010127966065
# 5            0  6E40FEB6  354121934453580  410010127966065
# 9            0  6E40FEB6  354121934453580  410010127966065
# ...        ...       ...              ...              ...
# 1582         0  3F300000  355066960060000  410010127966065
# 1583         0  3F300000  355066960060000  410010127966065
# 1584         0   80a3068  355066960060000  410010127966065
# 1585         0   80a3068  355066960060000  410010127966065
# 1586         0   80a3068  355066960060000  410010127966065
#
#                                                    Site
# 2     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 3     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 4     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 5     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 9     USHD8873__S_Imamaia colony GT Road Shadhra war...
# ...                                                 ...
# 1582                                                  ?
# 1583                                                  ?
# 1584                                                  ?
# 1585                                                  ?
# 1586                                                  ?
#
# [788 rows x 9 columns]

# %%
assert len(sms_data['Call Type'].unique()) == 2
assert len(sms_data) + len(call_data) == len(df_cleaned)

# %%
sms_data['B-Party'].unique()
# Out:
# array(['5299', '35323939', '923049585110', '4A617A7A', '9225', '9080',
#        '03024631717', '03138463280', '4554484E4943', '03138471965',
#        '03462861665', '00447786205094', '4170706C65', '923258069317',
#        '4A617A7A436173', '03434302772', '496E4472697665', '03215222251',
#        '57656172204547', '9397', '03258069317', '45474', '03008502826',
#        '526', '5452415820504B', '03457678809', '9890', '8225',
#        '03354349475', '923037579027', '8558', '4A415A5A', '81223',
#        '41494B20415445', '43726', '4C656', '923091797095', '4341524',
#        '923224365431', '03028133982', '03043397146', '8980',
#        '03426624789', '03454117873', '9729', '4A617A7A20476', '436',
#        '4661737465782E', '4A617A7A416476', '6055', '33313131',
#        '4A415A5A204361', '4A415A5A203447', '03456983575', '6C44454153',
#        '03137856757', '9228', '41636547616C6C', '03034670419',
#        '03007312318', '03244397186', '4A415A5A204', '99962', '4',
#        '03214729631', '6054', '923086639755', '4E444D41',
#        '53455454494E47', 'pple', '005126'], dtype=object)

# %%
sms_data.to_excel('data/sms_data_923214104372.xlsx', index=False)
call_data.to_excel('data/call_data_923214104372.xlsx', index=False)

# %%
def format_phone_number(number):
    # Remove any leading '+' if present
    number = number.lstrip('+')
    
    # Handle international numbers that start with '00'
    if number.startswith('00'):
        return number
    # Check if it already starts with the Pakistani country code '92' and has the correct length
    elif number.startswith('92') and len(number) == 12:
        return number
    # Handle local numbers starting with '03' and convert them to the correct format
    elif len(number) == 10 and number.startswith('03'):
        return '92' + number[1:]
    # Handle local numbers starting with '3' and convert them to the correct format
    elif len(number) == 11 and number.startswith('3'):
        return '92' + number
    # For other numbers, we will check if they seem like valid Pakistani numbers
    elif number.startswith('0') and len(number) == 11:
        return '92' + number[1:]
    elif number.startswith('92') and len(number) > 12:
        return '92' + number[-10:]
    else:
        # Keep the number as it is if it does not fit any of the above criteria
        return number

# %%
call_data['B-Party'] = call_data['B-Party'].apply(format_phone_number)
# Out:
# /var/folders/y2/f6l0j67j7cj6gm4wh3010c4w0000gn/T/ipykernel_30177/3790979675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   call_data['B-Party'] = call_data['B-Party'].apply(format_phone_number)

# %%
call_data.to_excel('data/call_data_923214104372.xlsx', index=False)

# %%
call_data
# Out:
#      Call Type       A-Party       B-Party         Date & Time  Duration  \
# 0     Outgoing  923214104372  923028480542 2023-09-01 09:54:14       134
# 1     Outgoing  923214104372  923028480542 2023-09-01 09:56:52        18
# 6     Outgoing  923214104372  923049585110 2023-09-01 10:11:34        59
# 7     InComing  923214104372  923214827411 2023-09-01 10:25:23        24
# 8     Outgoing  923214104372  923214453575 2023-09-01 10:33:02      1153
# ...        ...           ...           ...                 ...       ...
# 1572  InComing  923214104372  923105383978 2023-11-17 16:54:35        24
# 1573  Outgoing  923214104372  923002520080 2023-11-17 17:55:08      1122
# 1574  Outgoing  923214104372  923258069317 2023-11-17 21:00:42       279
# 1577  Outgoing  923214104372  923002520080 2023-11-18 08:27:21        29
# 1578  Outgoing  923214104372  923002520080 2023-11-18 08:35:13       103
#
#        Cell ID             IMEI             IMSI  \
# 0     6E40FEB6  354121934453580  410010127966065
# 1     6E40FEB6  354121934453580  410010127966065
# 6     6E40FEB6  354121934453580  410010127966065
# 7     6E40FEB6  354121934453580  410010127966065
# 8     6E40FEB6  354121934453580  410010127966065
# ...        ...              ...              ...
# 1572  3F30596B  354121934453580  410010127966065
# 1573  3F30596B  354121934453580  410010127966065
# 1574  3F30596B  354121934453580  410010127966065
# 1577  3F30596B  354121934453580  410010127966065
# 1578  3F30596B  354121934453580  410010127966065
#
#                                                    Site
# 0     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 1     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 6     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 7     USHD8873__S_Imamaia colony GT Road Shadhra war...
# 8     USHD8873__S_Imamaia colony GT Road Shadhra war...
# ...                                                 ...
# 1572  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1573  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1574  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1577  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
# 1578  ULHR9153__S_GulEDaman, OHWT at Accounts Group ...
#
# [799 rows x 9 columns]

# %%
df_cleaned[df_cleaned.Site == '?'].Site.apply
# Out:
# <bound method Series.apply of 1581    ?
# 1582    ?
# 1583    ?
# 1584    ?
# 1585    ?
# 1586    ?
# Name: Site, dtype: object>

# %%
df_cleaned.Site[0]
# Out:
# 'USHD8873__S_Imamaia colony GT Road Shadhra warid_MDLH1121, Lane #1anexi imamaia colony GT Road Shadhra, Shahdara (3G)|31.64956000|74.28313000'

# %%
def parse_site_info(info_string):
    # Handle case where the string is '?'
    if info_string == '?':
        return {
            'Address': '',
            'Latitude': '',
            'Longitude': '',
            'Connection code': '',
            'Internet': ''
        }
    
    # Split the string by the pipe '|' delimiter
    parts = info_string.split('|')
    
    # Extract latitude and longitude if available
    latitude = parts[1] if len(parts) > 1 else ''
    longitude = parts[2] if len(parts) > 2 else ''
    
    # Further split the first part to get connection code and address with internet info
    first_part = parts[0].split(', ')
    
    # Extract the connection code
    connection_code = first_part[0].strip() if len(first_part) > 0 else ''
    
    # Extract the internet type and address
    address_internet = first_part[1].split(' (') if len(first_part) > 1 else [first_part[0], '']
    address = address_internet[0].strip() if len(address_internet) > 0 else ''
    internet = address_internet[1].replace(')', '').strip() if len(address_internet) > 1 else ''
    
    # Create a dictionary to hold the parsed information
    parsed_info = {
        'Address': address,
        'Latitude': latitude,
        'Longitude': longitude,
        'Connection code': connection_code,
        'Internet': internet
    }
    
    return parsed_info

# %%
parse_site_info(df_cleaned.Site[0])
# Out:
# {'Address': 'Lane #1anexi imamaia colony GT Road Shadhra',
#  'Latitude': '31.64956000',
#  'Longitude': '74.28313000',
#  'Connection code': 'USHD8873__S_Imamaia colony GT Road Shadhra warid_MDLH1121',
#  'Internet': ''}

# %%
# Apply the parsing function to each row and expand the resulting dictionaries into columns
parsed_df = df_cleaned.Site.apply(parse_site_info).apply(pd.Series)

# Combine the original DataFrame with the new columns
df_site_data = pd.concat([df_cleaned, parsed_df], axis=1)

# %%
df_site_data.drop(labels='Site', axis=1, inplace=True)
df_site_data.columns
# Out:
# Index(['Call Type', 'A-Party', 'B-Party', 'Date & Time', 'Duration', 'Cell ID',
#        'IMEI', 'IMSI', 'Address', 'Latitude', 'Longitude', 'Connection code',
#        'Internet'],
#       dtype='object')

# %%
df_site_data.to_excel('data/site_data_transformed_923214104372.xlsx', index=False)

# %%
df_site_data.describe()
# Out:
#             A-Party     Duration          IMEI          IMSI
# count  1.587000e+03  1587.000000  1.587000e+03  1.587000e+03
# mean   9.232141e+11    93.730939  3.541255e+14  4.100101e+14
# std    0.000000e+00   248.165738  5.801564e+10  0.000000e+00
# min    9.232141e+11     0.000000  3.541219e+14  4.100101e+14
# 25%    9.232141e+11     0.000000  3.541219e+14  4.100101e+14
# 50%    9.232141e+11     1.000000  3.541219e+14  4.100101e+14
# 75%    9.232141e+11    52.000000  3.541219e+14  4.100101e+14
# max    9.232141e+11  1800.000000  3.550670e+14  4.100101e+14

# %%
df_cleaned.describe()
# Out:
#             A-Party                    Date & Time     Duration          IMEI  \
# count  4.164000e+03                           4164  4164.000000  4.164000e+03
# mean   9.231342e+11  2024-01-07 10:18:44.261047040    65.737752  3.575188e+14
# min    9.231342e+11            2023-12-01 09:28:09     0.000000  3.575188e+14
# 25%    9.231342e+11     2023-12-14 16:53:38.500000     0.000000  3.575188e+14
# 50%    9.231342e+11     2024-01-07 14:20:21.500000    28.000000  3.575188e+14
# 75%    9.231342e+11  2024-01-27 20:29:02.750000128    65.000000  3.575188e+14
# max    9.231342e+11            2024-02-20 23:45:33  1800.000000  3.575188e+14
# std    0.000000e+00                            NaN   145.426368  6.250751e-02
#
#                IMSI
# count  4.164000e+03
# mean   4.100190e+14
# min    4.100190e+14
# 25%    4.100190e+14
# 50%    4.100190e+14
# 75%    4.100190e+14
# max    4.100190e+14
# std    0.000000e+00

# %%
df_cleaned[((df_cleaned['Call Type'] == 'InComing') | (df_cleaned['Call Type'] == 'Outgoing')) & (df_cleaned['Duration'] == 0)]
# Out:
#      Call Type       A-Party       B-Party         Date & Time  Duration  \
# 9     Outgoing  923134225557  923444655305 2023-12-01 11:10:27         0
# 165   Outgoing  923134225557  923467432582 2023-12-02 14:12:54         0
# 268   Outgoing  923134225557  923467432582 2023-12-04 10:13:24         0
# 569   InComing  923134225557  923154983399 2023-12-07 12:49:43         0
# 900   Outgoing  923134225557  923136601188 2023-12-13 11:05:52         0
# 1072  Outgoing  923134225557  923454306241 2023-12-15 11:13:05         0
# 1146  Outgoing  923134225557  923467432582 2023-12-16 16:08:28         0
# 2183  Outgoing  923134225557  923467432582 2024-01-09 13:41:51         0
# 2309  Outgoing  923134225557  923444655305 2024-01-11 20:49:59         0
# 2475  InComing  923134225557  923044831279 2024-01-15 10:19:28         0
# 2877  Outgoing  923134225557  923454706526 2024-01-22 10:16:46         0
# 2941  Outgoing  923134225557  923454706526 2024-01-23 13:49:50         0
# 3703  InComing  923134225557  923008417096 2024-02-11 14:42:59         0
#
#       Cell ID             IMEI             IMSI  \
# 9     1E5142C  357518816304740  410018958165565
# 165   1E5142C  357518816304740  410018958165565
# 268   1FAD002  357518816304740  410018958165565
# 569   1D6DF0B  357518816304740  410018958165565
# 900   1EA4C1F  357518816304740  410018958165565
# 1072  1D57D0C  357518816304740  410018958165565
# 1146  1EDC701  357518816304740  410018958165565
# 2183  1E51433  357518816304740  410018958165565
# 2309  1D5BE04  357518816304740  410018958165565
# 2475  1E51433  357518816304740  410018958165565
# 2877  1EDC701  357518816304740  410018958165565
# 2941  1E88603  357518816304740  410018958165565
# 3703  1E51433  357518816304740  410018958165565
#
#                                                    Site
# 9                                                     ?
# 165                                                   ?
# 268   LTE_LHR9744__S_MainRoadSabzazar_MDLH1312, Moha...
# 569                                                   ?
# 900                                                   ?
# 1072                                                  ?
# 1146  LTE_LHR6407__S_TalibGanj, Talib Ganj Lahore, P...
# 2183  LTE_LHR4180__S_Thokar_MDLH1098, Shah town Riaw...
# 2309  LTE_LHR0254__P_AliContinental, 1-Mozang Road, ...
# 2475  LTE_LHR4180__S_Thokar_MDLH1098, Shah town Riaw...
# 2877  LTE_LHR6407__S_TalibGanj, Talib Ganj Lahore, P...
# 2941  LTE_LHR5062__S_Lahore_Add_Capacity_7_MDLH2886,...
# 3703  LTE_LHR4180__S_Thokar_MDLH1098, Shah town Riaw...

# %%
df_site_data[((df_site_data['Call Type'] == 'InComing') | (df_site_data['Call Type'] == 'Outgoing')) & (df_site_data['Duration'] == 0)]
# Out:
#      Call Type       A-Party       B-Party         Date & Time  Duration  \
# 9     Outgoing  923134225557  923444655305 2023-12-01 11:10:27         0
# 165   Outgoing  923134225557  923467432582 2023-12-02 14:12:54         0
# 268   Outgoing  923134225557  923467432582 2023-12-04 10:13:24         0
# 569   InComing  923134225557  923154983399 2023-12-07 12:49:43         0
# 900   Outgoing  923134225557  923136601188 2023-12-13 11:05:52         0
# 1072  Outgoing  923134225557  923454306241 2023-12-15 11:13:05         0
# 1146  Outgoing  923134225557  923467432582 2023-12-16 16:08:28         0
# 2183  Outgoing  923134225557  923467432582 2024-01-09 13:41:51         0
# 2309  Outgoing  923134225557  923444655305 2024-01-11 20:49:59         0
# 2475  InComing  923134225557  923044831279 2024-01-15 10:19:28         0
# 2877  Outgoing  923134225557  923454706526 2024-01-22 10:16:46         0
# 2941  Outgoing  923134225557  923454706526 2024-01-23 13:49:50         0
# 3703  InComing  923134225557  923008417096 2024-02-11 14:42:59         0
#
#       Cell ID             IMEI             IMSI  \
# 9     1E5142C  357518816304740  410018958165565
# 165   1E5142C  357518816304740  410018958165565
# 268   1FAD002  357518816304740  410018958165565
# 569   1D6DF0B  357518816304740  410018958165565
# 900   1EA4C1F  357518816304740  410018958165565
# 1072  1D57D0C  357518816304740  410018958165565
# 1146  1EDC701  357518816304740  410018958165565
# 2183  1E51433  357518816304740  410018958165565
# 2309  1D5BE04  357518816304740  410018958165565
# 2475  1E51433  357518816304740  410018958165565
# 2877  1EDC701  357518816304740  410018958165565
# 2941  1E88603  357518816304740  410018958165565
# 3703  1E51433  357518816304740  410018958165565
#
#                                                 Address     Latitude  \
# 9
# 165
# 268   Mohalla Said Pur Main Bazar Said Pur Shah Fare...  31.52266000
# 569
# 900
# 1072
# 1146                                  Talib Ganj Lahore     31.41674
# 2183               Shah town Riawing Road tohker Lahore  31.46881000
# 2309                                      1-Mozang Road      31.5624
# 2475               Shah town Riawing Road tohker Lahore  31.46881000
# 2877                                  Talib Ganj Lahore     31.41674
# 2941              Pakki Thathi Allama Iqbal Road Lahore  31.53680000
# 3703               Shah town Riawing Road tohker Lahore  31.46881000
#
#         Longitude                                Connection code Internet
# 9
# 165
# 268   74.27780000       LTE_LHR9744__S_MainRoadSabzazar_MDLH1312       4G
# 569
# 900
# 1072
# 1146     74.22245                       LTE_LHR6407__S_TalibGanj
# 2183  74.24122000                 LTE_LHR4180__S_Thokar_MDLH1098       4G
# 2309      74.3118                  LTE_LHR0254__P_AliContinental
# 2475  74.24122000                 LTE_LHR4180__S_Thokar_MDLH1098       4G
# 2877     74.22245                       LTE_LHR6407__S_TalibGanj
# 2941  74.29135000  LTE_LHR5062__S_Lahore_Add_Capacity_7_MDLH2886       4G
# 3703  74.24122000                 LTE_LHR4180__S_Thokar_MDLH1098       4G

# %%
df_site_data.in
# Out:
# RangeIndex(start=0, stop=4164, step=1)

# %%
df_site_data[((df_site_data['Call Type'] == 'InComing') | (df_site_data['Call Type'] == 'Outgoing')) & (df_site_data['Duration'] == 0)].index.equals(df_cleaned[((df_cleaned['Call Type'] == 'InComing') | (df_cleaned['Call Type'] == 'Outgoing')) & (df_cleaned['Duration'] == 0)].index)
# Out:
# True

# %% [markdown]
# # Line tracking Chart

# %%
import pandas as pd

# %%
raw_data = pd.read_excel('data/site_data_transformed_923214104372.xlsx')
raw_data.head(5)
# Out:
#       Call Type       A-Party       B-Party         Date & Time  Duration  \
# 0      Outgoing  923214104372   03028480542 2023-09-01 09:54:14       134
# 1      Outgoing  923214104372   03028480542 2023-09-01 09:56:52        18
# 2  Outgoing SMS  923214104372          5299 2023-09-01 09:57:09         0
# 3  Incoming SMS  923214104372      35323939 2023-09-01 09:57:21         0
# 4  Incoming SMS  923214104372  923049585110 2023-09-01 10:11:24         0
#
#     Cell ID             IMEI             IMSI  \
# 0  6E40FEB6  354121934453580  410010127966065
# 1  6E40FEB6  354121934453580  410010127966065
# 2  6E40FEB6  354121934453580  410010127966065
# 3  6E40FEB6  354121934453580  410010127966065
# 4  6E40FEB6  354121934453580  410010127966065
#
#                                        Address  Latitude  Longitude  \
# 0  Lane #1anexi imamaia colony GT Road Shadhra  31.64956   74.28313
# 1  Lane #1anexi imamaia colony GT Road Shadhra  31.64956   74.28313
# 2  Lane #1anexi imamaia colony GT Road Shadhra  31.64956   74.28313
# 3  Lane #1anexi imamaia colony GT Road Shadhra  31.64956   74.28313
# 4  Lane #1anexi imamaia colony GT Road Shadhra  31.64956   74.28313
#
#                                      Connection code Internet
# 0  USHD8873__S_Imamaia colony GT Road Shadhra war...      NaN
# 1  USHD8873__S_Imamaia colony GT Road Shadhra war...      NaN
# 2  USHD8873__S_Imamaia colony GT Road Shadhra war...      NaN
# 3  USHD8873__S_Imamaia colony GT Road Shadhra war...      NaN
# 4  USHD8873__S_Imamaia colony GT Road Shadhra war...      NaN

# %% [markdown]
# ## Sample Chart

# %%
import pydeck as pdk

DATA_URL = {
    "AIRPORTS": "https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/line/airports.json",
    "FLIGHT_PATHS": "https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/line/heathrow-flights.json",  # noqa
}

INITIAL_VIEW_STATE = pdk.ViewState(latitude=47.65, longitude=7, zoom=4.5, max_zoom=16, pitch=50, bearing=0)

# RGBA value generated in Javascript by deck.gl's Javascript expression parser
GET_COLOR_JS = [
    "255 * (1 - (start[2] / 10000) * 2)",
    "128 * (start[2] / 10000)",
    "255 * (start[2] / 10000)",
    "255 * (1 - (start[2] / 10000))",
]

scatterplot = pdk.Layer(
    "ScatterplotLayer",
    DATA_URL["AIRPORTS"],
    radius_scale=20,
    get_position="coordinates",
    get_fill_color=[255, 140, 0],
    get_radius=60,
    pickable=True,
)

line_layer = pdk.Layer(
    "LineLayer",
    DATA_URL["FLIGHT_PATHS"],
    get_source_position="start",
    get_target_position="end",
    get_color=GET_COLOR_JS,
    get_width=10,
    highlight_color=[255, 255, 0],
    picking_radius=10,
    auto_highlight=True,
    pickable=True,
)

layers = [scatterplot, line_layer]

r = pdk.Deck(layers=layers, initial_view_state=INITIAL_VIEW_STATE)
r.to_html("line_layer.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.9.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 0,
#     &quot;latitude&quot;: 47.65,
#     &quot;longitude&quot;: 7,
#     &quot;maxZoom&quot;: 16,
#     &quot;pitch&quot;: 50,
#     &quot;zoom&quot;: 4.5
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: &quot;https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/line/airports.json&quot;,
#       &quot;getFillColor&quot;: [
#         255,
#         140,
#         0
#       ],
#       &quot;getPosition&quot;: &quot;@@=coordinates&quot;,
#       &quot;getRadius&quot;: 60,
#       &quot;id&quot;: &quot;1c9cd4e9-8372-4cdc-a960-90a6db3c76bf&quot;,
#       &quot;pickable&quot;: true,
#       &quot;radiusScale&quot;: 20
#     },
#     {
#       &quot;@@type&quot;: &quot;LineLayer&quot;,
#       &quot;autoHighlight&quot;: true,
#       &quot;data&quot;: &quot;https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/line/heathrow-flights.json&quot;,
#       &quot;getColor&quot;: &quot;@@=[255 * (1 - (start[2] / 10000) * 2), 128 * (start[2] / 10000), 255 * (start[2] / 10000), 255 * (1 - (start[2] / 10000))]&quot;,
#       &quot;getSourcePosition&quot;: &quot;@@=start&quot;,
#       &quot;getTargetPosition&quot;: &quot;@@=end&quot;,
#       &quot;getWidth&quot;: 10,
#       &quot;highlightColor&quot;: [
#         255,
#         255,
#         0
#       ],
#       &quot;id&quot;: &quot;5c4ddfba-1130-4dba-aeb9-dbd70167a414&quot;,
#       &quot;pickable&quot;: true,
#       &quot;pickingRadius&quot;: 10
#     }
#   ],
#   &quot;mapProvider&quot;: &quot;carto&quot;,
#   &quot;mapStyle&quot;: &quot;https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json&quot;,
#   &quot;views&quot;: [
#     {
#       &quot;@@type&quot;: &quot;MapView&quot;,
#       &quot;controller&quot;: true
#     }
#   ]
# };
#     const tooltip = true;
#     const customLibraries = null;
#     const configuration = null;
#
#     const deckInstance = createDeck({
#                   container,
#       jsonInput,
#       tooltip,
#       customLibraries,
#       configuration
#     });
#
#   &lt;/script&gt;
# &lt;/html&gt;"
#         ></iframe>

# %%
df = raw_data

if 'Date & Time' in df.columns:
    df['Date & Time'] = pd.to_datetime(df['Date & Time'], errors='coerce')
    df = df.dropna(subset=['Date & Time'])  # Drop rows where 'Date & Time' is NaT
else:
    print("The 'Date & Time' column is missing or empty!")

# Check for valid Latitude and Longitude data
df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')
df = df.dropna(subset=['Latitude', 'Longitude'])
# Preview the processed data
# st.write(df[['Date & Time', 'Latitude', 'Longitude']].head())
# Create the start and end positions for each movement
df['start'] = df[['Longitude', 'Latitude']].shift(1).apply(list, axis=1)  # Previous location as list [Longitude, Latitude]
print(df['start'])
df = df.dropna()  # Drop the first row as it doesn't have a previous location
# Color based on time (using a gradient of blue to red)
df['time_norm'] = (df['Date & Time'] - df['Date & Time'].min()) / (df['Date & Time'].max() - df['Date & Time'].min())  # Normalize time
df['color'] = df['time_norm'].apply(lambda x: [255 * (1 - x), 128 * x, 255 * x, 200])  # RGBA gradient based on time
# Define the layers
scatterplot = pdk.Layer(
    "ScatterplotLayer",
    data=df,
    get_position=["Longitude", "Latitude"],
    get_fill_color=[255, 140, 0],  # Static color for points
    get_radius=100,
    pickable=True,
)
line_layer = pdk.Layer(
    "LineLayer",
    data=df,
    get_source_position="start",  # The previous point as a list
    get_target_position=["Longitude", "Latitude"],  # The current point
    get_color="color",  # Use the color calculated based on time
    get_width=5,
    auto_highlight=True,
    pickable=True,
)
# Initial map view
initial_view_state = pdk.ViewState(
    latitude=df['Latitude'].mean(),
    longitude=df['Longitude'].mean(),
    zoom=11,
    pitch=50,
)

    # Create the Deck.gl map
layers = [scatterplot, line_layer]
r = pdk.Deck(layers=layers, initial_view_state=initial_view_state, tooltip={"text": "{Date & Time}"})
r.to_html("line_layer.html")
# Out:
# 0                 [nan, nan]
# 1       [74.28313, 31.64956]
# 2       [74.28313, 31.64956]
# 3       [74.28313, 31.64956]
# 4       [74.28313, 31.64956]
#                 ...
# 1576      [74.2842, 31.4272]
# 1577      [74.2842, 31.4272]
# 1578      [74.2842, 31.4272]
# 1579      [74.2842, 31.4272]
# 1580      [74.2842, 31.4272]
# Name: start, Length: 1581, dtype: object
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.9.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 31.451300712626722,
#     &quot;longitude&quot;: 74.27088470433179,
#     &quot;pitch&quot;: 50,
#     &quot;zoom&quot;: 11
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;A-Party&quot;: 923214104372,
#           &quot;Address&quot;: &quot;PLOT MEASURING 35x45  Shahdara Railway Station.&quot;,
#           &quot;B-Party&quot;: &quot;9080&quot;,
#           &quot;Call Type&quot;: &quot;Incoming SMS&quot;,
#           &quot;Cell ID&quot;: &quot;6E4090B6&quot;,
#           &quot;Connection code&quot;: &quot;USHD3949__P_ShahdaraRailways&quot;,
#           &quot;Date &amp; Time&quot;: {},
#           &quot;Duration&quot;: 0,
#           &quot;IMEI&quot;: 354121934453580,
#           &quot;IMSI&quot;: 410010127966065,
#           &quot;Internet&quot;: &quot;3G&quot;,
#           &quot;Latitude&quot;: 31.642944,
#           &quot;Longitude&quot;: 74.286861,
#           &quot;color&quot;: [
#             255.0,
#             0.0,
#             0.0,
#             200
#           ],
#           &quot;start&quot;: [
#             74.28313,
#             31.64956
#           ],
#           &quot;time_norm&quot;: 0.0
#         },
#         {
#           &quot;A-Party&quot;: 923214104372,
#           &quot;Address&quot;: &quot;PLOT MEASURING 35x45  Shahdara Railway Station.&quot;,
#           &quot;B-Party&quot;: &quot;9080&quot;,
#           &quot;Call Type&quot;: &quot;Incoming SMS&quot;,
#           &quot;Cell ID&quot;: &quot;6E4090B6&quot;,
#           &quot;Connection code&quot;: &quot;USHD3949__P_ShahdaraRailways&quot;,
#           &quot;Date &amp; Time&quot;: {},
#           &quot;Duration&quot;: 0,
#           &quot;IMEI&quot;: 354121934453580,
#           &quot;IMSI&quot;: 410010127966065,
#           &quot;Internet&quot;: &quot;3G&quot;,
#           &quot;Latitude&quot;: 31.642944,
#           &quot;Longitude&quot;: 74.286861,
#           &quot;color&quot;: [
#             254.9990412908151,
#             0.0004812344143963681,
#             0.0009587091849302646,
#             200
#           ],
#           &quot;start&quot;: [
#             74.286861,
#             31.642944
#           ],
#           &quot;time_norm&quot;: 3.759643862471626e-06
#         },
#         {
#           &quot;A-Party&quot;: 923214104372,
#           &quot;Address&quot;: &quot;PLOT MEASURING 35x45  Shahdara Railway Station.&quot;,
#           &quot;B-Party&quot;: &quot;9225&quot;,
#           &quot;Call Type&quot;: &quot;Incoming SMS&quot;,
#           &quot;Cell ID&quot;: &quot;6E4090B6&quot;,
#           &quot;Connection code&quot;: &quot;USHD3949__P_ShahdaraRailways&quot;,
#           &quot;Date &amp; Time&quot;: {},
#           &quot;Duration&quot;: 0,
#           &quot;IMEI&quot;: 354121934453580,
#           &quot;IMSI&quot;: 410010127966065,
#           &quot;Internet&quot;: &quot;3G&quot;,
#           &quot;Latitude&quot;: 31.642944,
#           &quot;Longitude&quot;: 74.286861,
#           &quot;color&quot;: [
#             254.9933273840729,
#             0.003349391524198722,
#             0.006672615927114641,
#             200
#           ],
#           &quot;start&quot;: [
#             74.286861,
#             31.642944
#           ],
#           &quot;time_norm&quot;: 2.6167121282802515e-05
#         },
#         {
#           &quot;A-Party&quot;: 923214104372,
#           &quot;Address&quot;: &quot;Street No 10 Jinah Colony Near General Bus stand Sargodha&quot;,
#           &quot;B-Party&quot;: &quot;03024631717&quot;,
#           &quot;Call Type&quot;: &quot;InComing&quot;,
#           &quot;Cell ID&quot;: &quot;6610BD44&quot;,
#           &quot;Connection code&quot;: &quot;SGD7627__S_Jinnah_Colony Warid_SG1863&quot;,
#           &quot;Date &amp; Time&quot;: {},
#           &quot;Duration&quot;: 123,
#           &quot;IMEI&quot;: 354121934453580,
#           &quot;IMSI&quot;: 410010127966065,
#           &quot;Internet&quot;: &quot;2G&quot;,
#           &quot;Latitude&quot;: 32.07615,
#           &quot;Longitude&quot;: 72.69517,
#           &quot;color&quot;: [
#             253.50226616293455,
#             0.7518036515465821,
#             1.4977338370654565,
#             200
#           ],
#           &quot;start&quot;: [
#             72.91877,
#             32.15753
#           ],
#           &quot;time_norm&quot;: 0.005873466027707673
#         },
#         {
#           &quot;A-Party&quot;: 923214104372,
#           &quot;Address&quot;: &quot;PLOT MEASURING 35x45  Shahdara Railway Station.&quot;,
#           &quot;B-Party&quot;: &quot;03245550525&quot;,
#           &quot;Call Type&quot;: &quot;Outgoing&quot;,
#           &quot;Cell ID&quot;: &quot;6E4090B6&quot;,
#           &quot;Connection code&quot;: &quot;USHD3949__P_ShahdaraRailways&quot;,
#           &quot;Date &amp; Time&quot;: {},
#           &quot;Duration&quot;: 22,
#           &quot;IMEI&quot;: 354121934453580,
#           &quot;IMSI&quot;: 410010127966065,
#           &quot;Internet&quot;: &quot;3G&quot;,
#           &quot;Latitude&quot;: 31.642944,
#           &quot;Longitude&quot;: 74.286861,
#           &quot;color&quot;: [
#             250.21005882188402,
#             2.4043626305837105,
#             4.789941178115986,
#             200
#           ],
#           &quot;start&quot;: [
#             74.28313,
#             31.64956
#           ],
#           &quot;time_norm&quot;: 0.018784083051435238
#         },
#         {
#           &quot;A-Party&quot;: 923214104372,
#           &quot;Address&quot;: &quot;PLOT MEASURING 35x45  Shahdara Railway Station.&quot;,
#           &quot;B-Party&quot;: &quot;03218403525&quot;,
#           &quot;Call Type&quot;: &quot;InComing&quot;,
#           &quot;Cell ID&quot;: &quot;6E4090B6&quot;,
#           &quot;Connection code&quot;: &quot;USHD3949__P_ShahdaraRailways&quot;,
#           &quot;Date &amp; Time&quot;: {},
#           &quot;Duration&quot;: 18,
#           &quot;IMEI&quot;: 354121934453580,
#           &quot;IMSI&quot;: 410010127966065,
#           &quot;Internet&quot;: &quot;3G&quot;,
#           &quot;Latitude&quot;: 31.642944,
#           &quot;Longitude&quot;: 74.286861,
#           &quot;color&quot;: [
#             247.36376629692825,
#             3.8330898587967996,
#             7.636233703071749,
#             200
#           ],
#           &quot;start&quot;: [
#             74.28313,
#             31.64956
#           ],
#           &quot;time_norm&quot;: 0.029946014521849997
#         },
#         {
#           &quot;A-Party&quot;: 923214104372,
#           &quot;Address&quot;: &quot;PLOT MEASURING 35x45  Shahdara Railway Station.&quot;,
#           &quot;B-Party&quot;: &quot;923049585110&quot;,
#           &quot;Call Type&quot;: &quot;Incoming SMS&quot;,
#           &quot;Cell ID&quot;: &quot;6E4090B6&quot;,
#           &quot;Connection code&quot;: &quot;USHD3949__P_ShahdaraRailways&quot;,
#           &quot;Date &amp; Time&quot;: {},
#           &quot;Dur

# %% [markdown]
# ### Using Plotly

# %%
import plotly.express as px
import plotly.graph_objects as go


def line_tracking_chart(df):
    # Ensure the 'Date & Time' column is in datetime format and not empty

    df = df.sort_values(by='Date & Time')
    fig = go.Figure()

    # Extract data from the DataFrame
    latitudes = df['Latitude'].values
    longitudes = df['Longitude'].values
    times = df['Date & Time'].dt.strftime('%Y-%m-%d %H:%M:%S').values  # Time formatted for hover text
    
    color_data = df['Call Type'].apply(
        lambda x: [255, 0, 0, 255] if x == 'InComing' else  # Red
                ([0, 0, 255, 255] if x == 'Outgoing' else  # Blue
                ([0, 128, 0, 255] if x == 'Incoming SMS' else  # Green
                    ([255, 165, 0, 255] if x == 'Outgoing SMS' else [255, 255, 255, 160])))  # Orange
    ).tolist()
    
    df['color'] = color_data

    # Add scatter points for locations with lines connecting them
    fig.add_trace(go.Scattermapbox(
        lat=latitudes,
        lon=longitudes,
        mode='markers+lines',
        marker=dict(
            size=8,
            color=df['color'],  # Color column for color-coding (you can add this based on a condition)
            showscale=True,
            colorscale='Viridis',  # You can customize the colorscale
        ),
        line=dict(
            width=2,
            color='blue'  # Customize line color
        ),
        hoverinfo='text',
        hovertext=[f'Time: {t}' for t in times]  # Show 'Date & Time' on hover
    ))

    # Add arrows to indicate the movement direction
    for i in range(len(df) - 1):
        fig.add_trace(go.Scattermapbox(
            lat=[latitudes[i], latitudes[i + 1]],
            lon=[longitudes[i], longitudes[i + 1]],
            mode='lines',
            line=dict(width=2, color='red'),  # Color for the arrows (can be customized)
            marker=dict(size=4),
            hoverinfo='none'
        ))

    # Mapbox configuration (you can use open-street-map without a token)
    fig.update_layout(
        mapbox=dict(
            style="open-street-map",
            center=dict(lat=latitudes.mean(), lon=longitudes.mean()),  # Center the map
            zoom=12  # Adjust zoom level for better visualization
        ),
        margin={"r": 0, "t": 0, "l": 0, "b": 0}  # Remove margins around the map
    )

    fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import plotly.express as px
#       2 import plotly.graph_objects as go
#       5 def line_tracking_chart(df):
#       6     # Ensure the 'Date & Time' column is in datetime format and not empty
#
# ModuleNotFoundError: No module named 'plotly'
